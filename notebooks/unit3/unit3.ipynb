# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to c:\users\borow\appdata\local\temp\pip-req-build-ysn__b_c
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit d29756c456caadbbebc15c35893674abb2453e0d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting sb3_contrib<3.0,>=2.8.0a0 (from rl_zoo3==2.8.0a0)
#   Downloading sb3_contrib-2.8.0a0-py3-none-any.whl.metadata (4.1 kB)
# Collecting gymnasium<1.3.0,>=0.29.1 (from rl_zoo3==2.8.0a0)
#   Using cached gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.8.0a0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tqdm (from rl_zoo3==2.8.0a0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting rich (from rl_zoo3==2.8.0a0)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting optuna>=3.0 (from rl_zoo3==2.8.0a0)
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Collecting pyyaml>=5.1 (from rl_zoo3==2.8.0a0)
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.8.0a0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.8.0a0)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting numpy>=1.21.0 (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a0)
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a0)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a0) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a0)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting wasabi (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting filelock (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Downloading filelock-3.20.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.9 in d:\projects\huggingface-rl\.venv\lib\site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0) (25.0)
# Collecting requests (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: setuptools>=38.3.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from pytablewriter~=1.2->rl_zoo3==2.8.0a0) (58.1.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting stable_baselines3<3.0,>=2.8.0a0 (from sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading stable_baselines3-2.8.0a2-py3-none-any.whl.metadata (4.8 kB)
# Collecting torch<3.0,>=2.3 (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached torch-2.9.1-cp310-cp310-win_amd64.whl.metadata (30 kB)
# Collecting pandas (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading matplotlib-3.10.8-cp310-cp310-win_amd64.whl.metadata (52 kB)
# Collecting sympy>=1.13.3 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a0) (2.9.0.post0)
# Collecting pytz>=2018.9 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: six>=1.5 in d:\projects\huggingface-rl\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a0) (1.17.0)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.8.0a0)
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.8.0a0)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna>=3.0->rl_zoo3==2.8.0a0)
#   Downloading sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.8.0a0)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting tomli (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.8.0a0)
#   Downloading tomli-2.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.8.0a0)
#   Downloading greenlet-3.3.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in d:\projects\huggingface-rl\.venv\lib\site-packages (from tqdm->rl_zoo3==2.8.0a0) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading fonttools-4.61.1-cp310-cp310-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading pillow-12.1.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting tzdata>=2022.7 (from pandas->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a0)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a0)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl_zoo3==2.8.0a0)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from rich->rl_zoo3==2.8.0a0) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.8.0a0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached gymnasium-1.2.3-py3-none-any.whl (952 kB)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Downloading sb3_contrib-2.8.0a0-py3-none-any.whl (92 kB)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading stable_baselines3-2.8.0a2-py3-none-any.whl (187 kB)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Using cached torch-2.9.1-cp310-cp310-win_amd64.whl (111.0 MB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 20.0 MB/s  0:00:00
# Downloading greenlet-3.3.0-cp310-cp310-win_amd64.whl (300 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading filelock-3.20.2-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl (15 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.1 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 21.8 MB/s  0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp310-cp310-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 20.8 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# Downloading pillow-12.1.0-cp310-cp310-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------- ----------------- 3.9/7.0 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 18.1 MB/s  0:00:00
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml): started
#   Building wheel for rl_zoo3 (pyproject.toml): finished with status 'done'
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.8.0a0-py3-none-any.whl size=78639 sha256=5ed3dfc8ab82311300568cc789c1dc6eae56d21a39d7fdf4b96da37d996dec03
#   Stored in directory: C:\Users\borow\AppData\Local\Temp\pip-ephem-wheel-cache-v3ngf6v6\wheels\5f\9b\c0\8af7ab740f894e9d66c7707eb4aa58087c9a71dd262e7e6174
# Successfully built rl_zoo3
# Installing collected packages: pytz, mpmath, farama-notifications, wasabi, urllib3, tzdata, tqdm, tomli, tcolorpy, sympy, pyyaml, pyparsing, pillow, pathvalidate, numpy, networkx, mdurl, MarkupSafe, kiwisolver, idna, greenlet, fsspec, fonttools, filelock, cycler, colorlog, cloudpickle, charset_normalizer, chardet, certifi, sqlalchemy, requests, pandas, mbstrdecoder, markdown-it-py, Mako, jinja2, gymnasium, contourpy, typepy, torch, shimmy, rich, matplotlib, huggingface-hub, alembic, stable_baselines3, optuna, huggingface_sb3, sb3_contrib, DataProperty, tabledata, pytablewriter, rl_zoo3
#
#    ----------------------------------------  0/54 [pytz]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#     ---------------------------------------  1/54 [mpmath]
#    -- -------------------------------------  3/54 [wasabi]
#    -- -------------------------------------  4/54 [urllib3]
#    -- -------------------------------------  4/54 [urllib3]
#    -- -------------------------------------  4/54 [urllib3]
#    --- ------------------------------------  5/54 [tzdata]
#    --- ------------------------------------  5/54 [tzdata]
#    ---- -----------------------------------  6/54 [tqdm]
#    ---- -----------------------------------  6/54 [tqdm]
#    ---- -----------------------------------  6/54 [tqdm]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------ ---------------------------------  9/54 [sympy]
#    ------- -------------------------------- 10/54 [pyyaml]
#    ------- -------------------------------- 10/54 [pyyaml]
#    -------- ------------------------------- 11/54 [pyparsing]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    -------- ------------------------------- 12/54 [pillow]
#    --------- ------------------------------ 13/54 [pathvalidate]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ---------- ----------------------------- 14/54 [numpy]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 15/54 [networkx]
#    ----------- ---------------------------- 16/54 [mdurl]
#    -------------- ------------------------- 19/54 [idna]
#    -------------- ------------------------- 20/54 [greenlet]
#    -------------- ------------------------- 20/54 [greenlet]
#    --------------- ------------------------ 21/54 [fsspec]
#    --------------- ------------------------ 21/54 [fsspec]
#    --------------- ------------------------ 21/54 [fsspec]
#    --------------- ------------------------ 21/54 [fsspec]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ---------------- ----------------------- 22/54 [fonttools]
#    ----------------- ---------------------- 23/54 [filelock]
#    ------------------- -------------------- 26/54 [cloudpickle]
#    -------------------- ------------------- 27/54 [charset_normalizer]
#    -------------------- ------------------- 28/54 [chardet]
#    -------------------- ------------------- 28/54 [chardet]
#    -------------------- ------------------- 28/54 [chardet]
#    -------------------- ------------------- 28/54 [chardet]
#    -------------------- ------------------- 28/54 [chardet]
#    -------------------- ------------------- 28/54 [chardet]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 30/54 [sqlalchemy]
#    ---------------------- ----------------- 31/54 [requests]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ----------------------- ---------------- 32/54 [pandas]
#    ------------------------- -------------- 34/54 [markdown-it-py]
#    ------------------------- -------------- 34/54 [markdown-it-py]
#    ------------------------- -------------- 34/54 [markdown-it-py]
#    ------------------------- -------------- 34/54 [markdown-it-py]
#    ------------------------- -------------- 34/54 [markdown-it-py]
#    ------------------------- -------------- 34/54 [markdown-it-py]
#    ------------------------- -------------- 35/54 [Mako]
#    ------------------------- -------------- 35/54 [Mako]
#    ------------------------- -------------- 35/54 [Mako]
#    ------------------------- -------------- 35/54 [Mako]
#    -------------------------- ------------- 36/54 [jinja2]
#    -------------------------- ------------- 36/54 [jinja2]
#    -------------------------- ------------- 36/54 [jinja2]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    --------------------------- ------------ 37/54 [gymnasium]
#    ---------------------------- ----------- 38/54 [contourpy]
#    ---------------------------- ----------- 39/54 [typepy]
#    ---------------------------- ----------- 39/54 [typepy]
#    ---------------------------- ----------- 39/54 [typepy]
#    ---------------------------- ----------- 39/54 [typepy]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ----------------------------- ---------- 40/54 [torch]
#    ------------------------------ --------- 41/54 [shimmy]
#    ------------------------------- -------- 42/54 [rich]
#    ------------------------------- -------- 42/54 [rich]
#    ------------------------------- -------- 42/54 [rich]
#    ------------------------------- -------- 42/54 [rich]
#    ------------------------------- -------- 42/54 [rich]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    ------------------------------- -------- 43/54 [matplotlib]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    -------------------------------- ------- 44/54 [huggingface-hub]
#    --------------------------------- ------ 45/54 [alembic]
#    --------------------------------- ------ 45/54 [alembic]
#    --------------------------------- ------ 45/54 [alembic]
#    --------------------------------- ------ 45/54 [alembic]
#    --------------------------------- ------ 45/54 [alembic]
#    ---------------------------------- ----- 46/54 [stable_baselines3]
#    ---------------------------------- ----- 46/54 [stable_baselines3]
#    ---------------------------------- ----- 46/54 [stable_baselines3]
#    ---------------------------------- ----- 46/54 [stable_baselines3]
#    ---------------------------------- ----- 46/54 [stable_baselines3]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ---------------------------------- ----- 47/54 [optuna]
#    ----------------------------------- ---- 48/54 [huggingface_sb3]
#    ------------------------------------ --- 49/54 [sb3_contrib]
#    ------------------------------------ --- 49/54 [sb3_contrib]
#    ------------------------------------- -- 50/54 [DataProperty]
#    ------------------------------------- -- 50/54 [DataProperty]
#    -------------------------------------- - 52/54 [pytablewriter]
#    -------------------------------------- - 52/54 [pytablewriter]
#    -------------------------------------- - 52/54 [pytablewriter]
#    -------------------------------------- - 52/54 [pytablewriter]
#    -------------------------------------- - 52/54 [pytablewriter]
#    ---------------------------------------  53/54 [rl_zoo3]
#    ---------------------------------------- 54/54 [rl_zoo3]
#
# Successfully installed DataProperty-1.1.0 Mako-1.3.10 MarkupSafe-3.0.3 alembic-1.17.2 certifi-2025.11.12 chardet-5.2.0 charset_normalizer-3.4.4 cloudpickle-3.1.2 colorlog-6.10.1 contourpy-1.3.2 cycler-0.12.1 farama-notifications-0.0.4 filelock-3.20.2 fonttools-4.61.1 fsspec-2025.12.0 greenlet-3.3.0 gymnasium-1.2.3 huggingface-hub-0.36.0 huggingface_sb3-3.0 idna-3.11 jinja2-3.1.6 kiwisolver-1.4.9 markdown-it-py-4.0.0 matplotlib-3.10.8 mbstrdecoder-1.1.4 mdurl-0.1.2 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 optuna-4.6.0 pandas-2.3.3 pathvalidate-3.3.1 pillow-12.1.0 pyparsing-3.3.1 pytablewriter-1.2.1 pytz-2025.2 pyyaml-6.0.3 requests-2.32.5 rich-14.2.0 rl_zoo3-2.8.0a0 sb3_contrib-2.8.0a0 shimmy-2.0.0 sqlalchemy-2.0.45 stable_baselines3-2.8.0a2 sympy-1.14.0 tabledata-1.3.4 tcolorpy-0.1.7 tomli-2.3.0 torch-2.9.1 tqdm-4.67.1 typepy-1.3.4 tzdata-2025.3 urllib3-2.6.2 wasabi-1.1.3
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo 'C:\Users\borow\AppData\Local\Temp\pip-req-build-ysn__b_c'
#   Running command git submodule update --init --recursive -q

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in d:\projects\huggingface-rl\.venv\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[atari]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[atari]) (0.0.4)
# Collecting ale_py>=0.9 (from gymnasium[atari])
#   Downloading ale_py-0.11.2-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Downloading ale_py-0.11.2-cp310-cp310-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 3.5/3.5 MB 20.6 MB/s  0:00:00
# Installing collected packages: ale_py
# Successfully installed ale_py-0.11.2
# Requirement already satisfied: gymnasium[accept-rom-license] in d:\projects\huggingface-rl\.venv\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[accept-rom-license]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[accept-rom-license]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[accept-rom-license]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\projects\huggingface-rl\.venv\lib\site-packages (from gymnasium[accept-rom-license]) (0.0.4)
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in d:\projects\huggingface-rl\.venv\lib\site-packages (from opencv-python) (2.2.6)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ------ --------------------------------- 6.3/39.0 MB 32.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.5/39.0 MB 25.2 MB/s eta 0:00:02
#    -------------------- ------------------- 20.2/39.0 MB 31.9 MB/s eta 0:00:01
#    --------------------------- ------------ 27.0/39.0 MB 32.3 MB/s eta 0:00:01
#    ------------------------------- -------- 30.7/39.0 MB 33.0 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.0 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 28.2 MB/s  0:00:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# RUN IN TERMINAL INSTEAD, TO PRINT LOGS PROPERLY
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 237162029
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 48),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1081     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 940      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1071     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 121      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1067     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1083     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1089     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1088     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1093     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1097     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1094     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1099     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1101     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1097     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1097     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9225     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1101     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1097     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 10427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1097     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1098     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 12007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1097     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1094     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 13744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1092     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1093     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1091     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 15488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1092     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 15951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1091     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 16523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1091     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 17262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1092     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 17819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1090     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 18574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1092     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 19653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1093     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 20086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1092     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 20781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1091     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 21356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1092     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 21810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1091     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 22524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1091     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 23145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1093     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24001    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1093     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 24684    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=197.00 +/- 48.44
# Episode length: 2713.00 +/- 538.13
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.71e+03 |
# |    mean_reward      | 197      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 913      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 25454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 917      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 26111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 922      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 27005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 923      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 27454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 926      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 27973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 929      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 28515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 932      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 29276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 935      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 29897    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 938      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 30571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 940      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 31062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 943      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 31674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 944      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 32314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 947      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 32889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 949      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 33489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 952      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 34181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 955      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 34948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 956      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 35629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 958      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 36342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 961      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 37120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 963      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 37790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 965      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 38449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 968      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 39430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 970      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 40129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 973      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 40915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 975      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 41760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 977      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 42527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.573    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 978      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 43161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 980      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 43892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 982      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 44859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 985      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 45881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 985      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 46565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 986      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 47300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 988      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 47889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 989      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 48556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 990      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 49342    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=175.00 +/- 137.51
# Episode length: 2246.60 +/- 508.99
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.25e+03 |
# |    mean_reward      | 175      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 911      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 50018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 912      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 50486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 913      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 50916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.49     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 914      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 51490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 917      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 52380    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 920      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 53286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 921      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 53876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 922      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 54511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 924      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 55412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 926      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 56057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 927      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 56605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 929      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 57781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.423    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 928      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 58256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 926      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 59314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 926      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 60077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 927      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 61136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 929      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 61956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 930      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 62528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 931      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 63483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 933      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 64204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 934      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 64864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 935      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 65372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 936      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 66101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 936      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 66481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 937      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 67165    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 939      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 67780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 940      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 68439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 941      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 68870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.307    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 943      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 69961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 944      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 70425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 946      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 71499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 946      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 71950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 947      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 72524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 947      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 72885    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.274    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 948      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 73377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 949      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 73925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 950      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 74563    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=169.00 +/- 102.15
# Episode length: 2221.80 +/- 503.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.22e+03 |
# |    mean_reward      | 169      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 891      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 75249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 892      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 75793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 894      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 76627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.235    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 895      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 77297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 897      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 78286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 897      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 78712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 898      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 79349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.207    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 900      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 80065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.201    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 901      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 80711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 902      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 81534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.185    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 904      |
# ...
# |    loss             | 0.0259   |
# |    n_updates        | 214153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 85       |
# |    time_elapsed     | 11217    |
# |    total_timesteps  | 957407   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00916  |
# |    n_updates        | 214351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 85       |
# |    time_elapsed     | 11227    |
# |    total_timesteps  | 958308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 214576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 85       |
# |    time_elapsed     | 11251    |
# |    total_timesteps  | 960487   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 215121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 85       |
# |    time_elapsed     | 11265    |
# |    total_timesteps  | 961710   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 215427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 85       |
# |    time_elapsed     | 11278    |
# |    total_timesteps  | 962869   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 215717   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 85       |
# |    time_elapsed     | 11294    |
# |    total_timesteps  | 964384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 216095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 85       |
# |    time_elapsed     | 11310    |
# |    total_timesteps  | 965777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 216444   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 85       |
# |    time_elapsed     | 11329    |
# |    total_timesteps  | 967410   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 216852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 85       |
# |    time_elapsed     | 11355    |
# |    total_timesteps  | 969726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 217431   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 85       |
# |    time_elapsed     | 11372    |
# |    total_timesteps  | 971202   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 217800   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 85       |
# |    time_elapsed     | 11386    |
# |    total_timesteps  | 972455   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 218113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 85       |
# |    time_elapsed     | 11401    |
# |    total_timesteps  | 973848   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 218461   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=583.00 +/- 94.85
# Episode length: 3928.20 +/- 642.99
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.93e+03 |
# |    mean_reward      | 583      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 85       |
# |    time_elapsed     | 11426    |
# |    total_timesteps  | 975142   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 218785   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 85       |
# |    time_elapsed     | 11449    |
# |    total_timesteps  | 977210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 219302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 85       |
# |    time_elapsed     | 11468    |
# |    total_timesteps  | 978898   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00989  |
# |    n_updates        | 219724   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 85       |
# |    time_elapsed     | 11492    |
# |    total_timesteps  | 981021   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 220255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 615      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 85       |
# |    time_elapsed     | 11512    |
# |    total_timesteps  | 982879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 220719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 85       |
# |    time_elapsed     | 11532    |
# |    total_timesteps  | 984595   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 221148   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 619      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 85       |
# |    time_elapsed     | 11552    |
# |    total_timesteps  | 986434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 221608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 626      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 85       |
# |    time_elapsed     | 11571    |
# |    total_timesteps  | 988033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 222008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 626      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 85       |
# |    time_elapsed     | 11585    |
# |    total_timesteps  | 989379   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 222344   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 620      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3940     |
# |    fps              | 85       |
# |    time_elapsed     | 11602    |
# |    total_timesteps  | 990903   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 222725   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 620      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3944     |
# |    fps              | 85       |
# |    time_elapsed     | 11620    |
# |    total_timesteps  | 992568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 223141   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 619      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3948     |
# |    fps              | 85       |
# |    time_elapsed     | 11628    |
# |    total_timesteps  | 993380   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 223344   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 618      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3952     |
# |    fps              | 85       |
# |    time_elapsed     | 11639    |
# |    total_timesteps  | 994424   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 223605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 617      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3956     |
# |    fps              | 85       |
# |    time_elapsed     | 11655    |
# |    total_timesteps  | 995899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 223974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 618      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3960     |
# |    fps              | 85       |
# |    time_elapsed     | 11676    |
# |    total_timesteps  | 997689   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 224422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 616      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3964     |
# |    fps              | 85       |
# |    time_elapsed     | 11689    |
# |    total_timesteps  | 998905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 224726   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=737.00 +/- 297.16
# Episode length: 4435.40 +/- 1059.31
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.44e+03 |
# |    mean_reward      | 737      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 224999   |
# ----------------------------------
# New best mean reward!
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_2

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml --device cuda
# Out:
# ^C
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 590661148
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 48),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 1000),
#              ('n_timesteps', 10000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_8
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.73e+03 |
# |    ep_rew_mean      | 35       |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 964      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 573      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+03 |
# |    ep_rew_mean      | 50       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 800      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1015     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000201 |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 501      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1732     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00986  |
# |    n_updates        | 182      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 433      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2343     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 335      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 393      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3099     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 524      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 376      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3701     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 675      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 362      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 4392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 847      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 354      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 5036     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 1008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 344      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 5772     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0016   |
# |    n_updates        | 1192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 339      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 6447     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 1361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 334      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 7465     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00297  |
# |    n_updates        | 1616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 331      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 7924     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 1730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 326      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 9032     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00307  |
# |    n_updates        | 2007     |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_8
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=11
# Loading logs/dqn\SpaceInvadersNoFrameskip-v4_11\SpaceInvadersNoFrameskip-v4.zip
# Stacking 4 frames
# Atari Episode Score: 270.00
# Atari Episode Length 2737
# Atari Episode Score: 75.00
# Atari Episode Length 1577
# Atari Episode Score: 75.00
# Atari Episode Length 1577
# Atari Episode Score: 190.00
# Atari Episode Length 2787
# Atari Episode Score: 180.00
# Atari Episode Length 1715
# Atari Episode Score: 145.00
# Atari Episode Length 1661
# Atari Episode Score: 445.00
# Atari Episode Length 3211
# Atari Episode Score: 295.00
# Atari Episode Length 2745
# Atari Episode Score: 200.00
# Atari Episode Length 1833
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=12
# Loading logs/dqn\SpaceInvadersNoFrameskip-v4_12\SpaceInvadersNoFrameskip-v4.zip
# Stacking 4 frames
# Atari Episode Score: 555.00
# Atari Episode Length 3612
# Atari Episode Score: 570.00
# Atari Episode Length 3579
# Atari Episode Score: 715.00
# Atari Episode Length 3707
# Atari Episode Score: 420.00
# Atari Episode Length 2785
# Atari Episode Score: 285.00
# Atari Episode Length 2541
# Atari Episode Score: 580.00
# Atari Episode Length 2392
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name _____________________ -orga _____________________ -f logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
